# %%
# %pip install pandas numpy matplotlib plotly seaborn scikit-learn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.3.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
# %matplotlib inline

# %%
data=pd.read_csv('jkh.csv')
data.head()
# Out:
#                      1.Жалобы на проблемы в квартире  \
# 0                                    Протекает крыша
# 1  Куда: Служба жилищного контроля истроительного...
# 2  ЗАЯВЛЕНИЕ\n о нарушении требований к содержани...
# 3                         Поврежден межпанельный шов
# 4  Куда: Служба жилищного контроля истроительного...
#
#                                2.Проблемы в подъезде  \
# 0                       Крысы и насекомые в подъезде
# 1  Куда: Служба жилищного контроля и строительног...
# 2  ЗАЯВЛЕНИЕ\nо нарушении требований к содержанию...
# 3                           Забита водосточная труба
# 4  Куда: Служба жилищного контроля и строительног...
#
#                                  3.Проблемы во дворе  \
# 0                                Образуются сосульки
# 1  Куда: Служба жилищного контроля и строительног...
# 2  ЗАЯВЛЕНИЕ\nо нарушении требований к содержанию...
# 3                               Трещины в фундаменте
# ...

# %%
data.head(1000)
# Out:
#                       1.Жалобы на проблемы в квартире  \
# 0                                     Протекает крыша
# 1   Куда: Служба жилищного контроля истроительного...
# 2   ЗАЯВЛЕНИЕ\n о нарушении требований к содержани...
# 3                          Поврежден межпанельный шов
# 4   Куда: Служба жилищного контроля истроительного...
# 5   ЗАЯВЛЕНИЕ\n о нарушении требований к содержани...
# 6                    Холод в квартире из-за отопления
# 7   Куда: Служба жилищного контроля и строительног...
# 8   ЗАЯВЛЕНИЕ\n о нарушении нормативов обеспечения...
# 9                                 Перепады напряжения
# 10  Куда: Служба жилищного контроля и строительног...
# 11  ЗАЯВЛЕНИЕ\n о нарушении нормативов обеспечения...
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# ...
