# %%
# %pip install spacy nltk numpy scikit-learn
import spacy
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer
from nltk import word_tokenize
nlp=spacy.load('ru_core_news_sm')
from nltk import word_tokenize
from nltk.corpus import stopwords
from nltk import SnowballStemmer
import math
import re
from collections import Counter as Count
# Out:
# ...
#
# ...

# %%
text='1 Глава Завещаю в той жизни Вам счастливыми быть И родимой Отчизне С честью дальше служить. Горевать — горделиво, Не клонясь головой. Ликовать — не хвастливоВ час победы самой. И беречь ее свято, Братья, счастье свое — В память воина-брата, Что погиб за нее.'

# %%
doc=nlp(text)

# %%
words=word_tokenize(text)
words
# Out:
# ['1',
#  'Глава',
#  'Завещаю',
#  'в',
#  'той',
#  'жизни',
#  'Вам',
#  'счастливыми',
#  'быть',
#  'И',
#  'родимой',
#  'Отчизне',
#  'С',
#  'честью',
#  'дальше',
#  'служить',
#  '.',
#  'Горевать',
#  '—',
#  'горделиво',
#  ',',
#  'Не',
#  'клонясь',
#  'головой',
#  '.',
#  'Ликовать',
#  '—',
#  'не',
#  'хвастливоВ',
#  'час',
#  'победы',
#  'самой',
#  '.',
#  'И',
#  'беречь',
#  'ее',
#  'свято',
#  ',',
#  'Братья',
#  ',',
#  'счастье',
#  'свое',
#  '—',
#  'В',
#  'память',
#  'воина-брата',
#  ',',
#  'Что',
#  'погиб',
#  'за',
#  'нее',
#  '.']

# %%
word_filtered=[token.text for token in doc if not token.is_punct and not token.is_stop]
word_filtered
# Out:
# ['1',
#  'Глава',
#  'Завещаю',
#  'жизни',
#  'счастливыми',
#  'родимой',
#  'Отчизне',
#  'честью',
#  'служить',
#  'Горевать',
#  'горделиво',
#  'клонясь',
#  'головой',
#  'Ликовать',
#  'хвастливоВ',
#  'час',
#  'победы',
#  'беречь',
#  'свято',
#  'Братья',
#  'счастье',
#  'память',
#  'воина',
#  'брата',
#  'погиб']

# %%
len(words)
# Out:
# 52

# %%
len(word_filtered)
# Out:
# 25

# %%
word_lemma=[token.lemma_ for token in doc if not token.is_punct and not token.is_stop]
word_lemma
# Out:
# ['1',
#  'глава',
#  'завещать',
#  'жизнь',
#  'счастливый',
#  'родимый',
#  'отчизна',
#  'честь',
#  'служить',
#  'горевать',
#  'горделивый',
#  'клониться',
#  'голова',
#  'ликовать',
#  'хвастливов',
#  'час',
#  'победа',
#  'беречь',
#  'святой',
#  'брат',
#  'счастие',
#  'память',
#  'воин',
#  'брат',
#  'погибнуть']

# %%
doc.vector
doc.similarity
# Out:
# <function Doc.similarity>

# %% [markdown]
# Д/З

# %%
with open("Last_volleys.txt", encoding="utf-8") as file:
    text = file.read()

# %%
words=word_tokenize(text)
words
# Out:
# ['1',
#  'Глава',
#  'Завещаю',
#  'в',
#  'той',
#  'жизни',
#  'Вам',
#  'счастливыми',
#  'быть',
#  'И',
#  'родимой',
#  'Отчизне',
#  'С',
#  'честью',
#  'дальше',
#  'служить',
#  '.',
#  'Горевать',
#  '—',
#  'горделиво',
#  ',',
#  'Не',
#  'клонясь',
#  'головой',
#  '.',
#  'Ликовать',
#  '—',
#  'не',
#  'хвастливо',
#  'В',
#  'час',
#  'победы',
#  'самой',
#  '.',
#  'И',
#  'беречь',
#  'ее',
#  'свято',
#  ',',
#  'Братья',
#  ',',
#  'счастье',
#  'свое',
#  '—',
#  'В',
#  'память',
#  'воина-брата',
#  ',',
#  'Что',
#  'погиб',
#  'за',
#  'нее',
#  '.',
#  'А.',
#  'Твардовский',
#  'В',
#  'двенадцатом',
#  'часу',
#  'ночи',
#  'капитан',
#  'Новиков',
#  'проверял',
#  'посты',
#  '.',
#  'Он',
#  'шел',
#  'по',
#  'высоте',
#  'в',
#  'черной',
#  'осенней',
#  'тьме',
#  ',',
#  'над',
#  'головой',
#  'густо',
#  'шумели',
#  'вершины',
#  'сосен',
#  '.',
#  'Острым',
#  'северным',
#  'холодом',
#  'дуло',
#  'с',
#  'Карпат',
#  ',',
#  'вся',
# ...

# %%
import nltk
nltk.download('stopwords')
stop = stopwords.words('russian')
stop
# Out:
# [nltk_data] Downloading package stopwords to C:\Users\Дима
# [nltk_data]     Титаренко\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# ['и',
#  'в',
#  'во',
#  'не',
#  'что',
#  'он',
#  'на',
#  'я',
#  'с',
#  'со',
#  'как',
#  'а',
#  'то',
#  'все',
#  'она',
#  'так',
#  'его',
#  'но',
#  'да',
#  'ты',
#  'к',
#  'у',
#  'же',
#  'вы',
#  'за',
#  'бы',
#  'по',
#  'только',
#  'ее',
#  'мне',
#  'было',
#  'вот',
#  'от',
#  'меня',
#  'еще',
#  'нет',
#  'о',
#  'из',
#  'ему',
#  'теперь',
#  'когда',
#  'даже',
#  'ну',
#  'вдруг',
#  'ли',
#  'если',
#  'уже',
#  'или',
#  'ни',
#  'быть',
#  'был',
#  'него',
#  'до',
#  'вас',
#  'нибудь',
#  'опять',
#  'уж',
#  'вам',
#  'ведь',
#  'там',
#  'потом',
#  'себя',
#  'ничего',
#  'ей',
#  'может',
#  'они',
#  'тут',
#  'где',
#  'есть',
#  'надо',
#  'ней',
#  'для',
#  'мы',
#  'тебя',
#  'их',
#  'чем',
#  'была',
#  'сам',
#  'чтоб',
#  'без',
#  'будто',
#  'чего',
# ...

# %%
tokenized_filtered = [token for token in words if token not in stop]
tokenized_filtered
# Out:
# ['1',
#  'Глава',
#  'Завещаю',
#  'той',
#  'жизни',
#  'Вам',
#  'счастливыми',
#  'И',
#  'родимой',
#  'Отчизне',
#  'С',
#  'честью',
#  'дальше',
#  'служить',
#  '.',
#  'Горевать',
#  '—',
#  'горделиво',
#  ',',
#  'Не',
#  'клонясь',
#  'головой',
#  '.',
#  'Ликовать',
#  '—',
#  'хвастливо',
#  'В',
#  'час',
#  'победы',
#  'самой',
#  '.',
#  'И',
#  'беречь',
#  'свято',
#  ',',
#  'Братья',
#  ',',
#  'счастье',
#  'свое',
#  '—',
#  'В',
#  'память',
#  'воина-брата',
#  ',',
#  'Что',
#  'погиб',
#  '.',
#  'А.',
#  'Твардовский',
#  'В',
#  'двенадцатом',
#  'часу',
#  'ночи',
#  'капитан',
#  'Новиков',
#  'проверял',
#  'посты',
#  '.',
#  'Он',
#  'шел',
#  'высоте',
#  'черной',
#  'осенней',
#  'тьме',
#  ',',
#  'головой',
#  'густо',
#  'шумели',
#  'вершины',
#  'сосен',
#  '.',
#  'Острым',
#  'северным',
#  'холодом',
#  'дуло',
#  'Карпат',
#  ',',
#  'вся',
#  'высота',
#  'гудела',
#  ',',
#  'точно',
#  'гулко',
#  'вибрировала',
#  'непрерывными',
# ...

# %%
len(words)
# Out:
# 61115

# %%
len(tokenized_filtered)
# Out:
# 48990

# %%
stemmer = SnowballStemmer(language='russian')
tokenized = nltk.word_tokenize(text)
stemmed = [stemmer.stem(tokenized_filtered) for tokenized_filtered in tokenized]
stemmed
# Out:
# ['1',
#  'глав',
#  'завеща',
#  'в',
#  'то',
#  'жизн',
#  'вам',
#  'счастлив',
#  'быт',
#  'и',
#  'родим',
#  'отчизн',
#  'с',
#  'чест',
#  'дальш',
#  'служ',
#  '.',
#  'горева',
#  '—',
#  'горделив',
#  ',',
#  'не',
#  'клон',
#  'голов',
#  '.',
#  'ликова',
#  '—',
#  'не',
#  'хвастлив',
#  'в',
#  'час',
#  'побед',
#  'сам',
#  '.',
#  'и',
#  'береч',
#  'е',
#  'свят',
#  ',',
#  'брат',
#  ',',
#  'счаст',
#  'сво',
#  '—',
#  'в',
#  'памя',
#  'воина-брат',
#  ',',
#  'что',
#  'погиб',
#  'за',
#  'не',
#  '.',
#  'а.',
#  'твардовск',
#  'в',
#  'двенадцат',
#  'час',
#  'ноч',
#  'капита',
#  'новик',
#  'проверя',
#  'пост',
#  '.',
#  'он',
#  'шел',
#  'по',
#  'высот',
#  'в',
#  'черн',
#  'осен',
#  'тьме',
#  ',',
#  'над',
#  'голов',
#  'густ',
#  'шумел',
#  'вершин',
#  'сос',
#  '.',
#  'остр',
#  'северн',
#  'холод',
#  'дул',
#  'с',
#  'карпат',
#  ',',
#  'вся',
#  'высот',
#  'гудел',
#  ',',
#  'точн',
#  'гулк',
#  'вибрирова',
#  'под',
# ...

# %%
len(stemmed)
# Out:
# 61115

# %% [markdown]
# Forgive_us!

# %%
with open("Forgive_us!.txt", encoding="utf-8") as file:
    text_1 = file.read()

# %%
words=word_tokenize(text_1)
words
# Out:
# ['Юрий',
#  'Бондарев',
#  '«',
#  'ПРОСТИТЕ',
#  'НАС',
#  '!',
#  '»',
#  'Южный',
#  'экспресс',
#  'задержался',
#  'здесь',
#  'не',
#  'более',
#  'пяти',
#  'минут',
#  '.',
#  'Павел',
#  'Георгиевич',
#  'долго',
#  'стоял',
#  'на',
#  'безлюдной',
#  'платформе',
#  'и',
#  'слушал',
#  'горячую',
#  'трескотню',
#  'кузнечиков',
#  'за',
#  'насыпью',
#  'степного',
#  'разъезда',
#  '.',
#  'После',
#  'духоты',
#  'вагона',
#  ',',
#  'утомительных',
#  'дорожных',
#  'разговоров',
#  'в',
#  'накуренном',
#  'купе',
#  'за',
#  'полночным',
#  'преферансом',
#  ',',
#  'ненужных',
#  'знакомств',
#  ',',
#  'после',
#  'надоедливого',
#  'поскрипывания',
#  'полок',
#  'Павла',
#  'Георгиевича',
#  'охватила',
#  'неправдоподобная',
#  'тишина',
#  ',',
#  'казалось',
#  ',',
#  'совсем',
#  'как',
#  'в',
#  'детстве',
#  '.',
#  'Он',
#  'не',
#  'без',
#  'удовольствия',
#  'сел',
#  'на',
#  'чемодан',
#  ',',
#  'перекинул',
#  'плащ',
#  'через',
#  'плечо',
# ...

# %%
import nltk
nltk.download('stopwords')
stop = stopwords.words('russian')
stop
# Out:
# [nltk_data] Downloading package stopwords to C:\Users\Дима
# [nltk_data]     Титаренко\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# ['и',
#  'в',
#  'во',
#  'не',
#  'что',
#  'он',
#  'на',
#  'я',
#  'с',
#  'со',
#  'как',
#  'а',
#  'то',
#  'все',
#  'она',
#  'так',
#  'его',
#  'но',
#  'да',
#  'ты',
#  'к',
#  'у',
#  'же',
#  'вы',
#  'за',
#  'бы',
#  'по',
#  'только',
#  'ее',
#  'мне',
#  'было',
#  'вот',
#  'от',
#  'меня',
#  'еще',
#  'нет',
#  'о',
#  'из',
#  'ему',
#  'теперь',
#  'когда',
#  'даже',
#  'ну',
#  'вдруг',
#  'ли',
#  'если',
#  'уже',
#  'или',
#  'ни',
#  'быть',
#  'был',
#  'него',
#  'до',
#  'вас',
#  'нибудь',
#  'опять',
#  'уж',
#  'вам',
#  'ведь',
#  'там',
#  'потом',
#  'себя',
#  'ничего',
#  'ей',
#  'может',
#  'они',
#  'тут',
#  'где',
#  'есть',
#  'надо',
#  'ней',
#  'для',
#  'мы',
#  'тебя',
#  'их',
#  'чем',
#  'была',
#  'сам',
#  'чтоб',
#  'без',
#  'будто',
#  'чего',
# ...

# %%
tokenized_filtered = [token for token in words if token not in stop]
tokenized_filtered
# Out:
# ['Юрий',
#  'Бондарев',
#  '«',
#  'ПРОСТИТЕ',
#  'НАС',
#  '!',
#  '»',
#  'Южный',
#  'экспресс',
#  'задержался',
#  'пяти',
#  'минут',
#  '.',
#  'Павел',
#  'Георгиевич',
#  'долго',
#  'стоял',
#  'безлюдной',
#  'платформе',
#  'слушал',
#  'горячую',
#  'трескотню',
#  'кузнечиков',
#  'насыпью',
#  'степного',
#  'разъезда',
#  '.',
#  'После',
#  'духоты',
#  'вагона',
#  ',',
#  'утомительных',
#  'дорожных',
#  'разговоров',
#  'накуренном',
#  'купе',
#  'полночным',
#  'преферансом',
#  ',',
#  'ненужных',
#  'знакомств',
#  ',',
#  'надоедливого',
#  'поскрипывания',
#  'полок',
#  'Павла',
#  'Георгиевича',
#  'охватила',
#  'неправдоподобная',
#  'тишина',
#  ',',
#  'казалось',
#  ',',
#  'детстве',
#  '.',
#  'Он',
#  'удовольствия',
#  'сел',
#  'чемодан',
#  ',',
#  'перекинул',
#  'плащ',
#  'плечо',
#  'сидел',
#  ',',
#  'оглядываясь',
#  'счастливым',
#  'облегчением',
#  '.',
#  'Хотя',
#  'роду',
#  'своей',
#  'профессии',
#  'приходилось',
#  'ездить',
# ...

# %%
stemmer = SnowballStemmer(language='russian')
tokenized = nltk.word_tokenize(text_1)
stemmed = [stemmer.stem(tokenized_filtered) for tokenized_filtered in tokenized]
stemmed
# Out:
# ['юр',
#  'бондар',
#  '«',
#  'прост',
#  'нас',
#  '!',
#  '»',
#  'южн',
#  'экспресс',
#  'задержа',
#  'зде',
#  'не',
#  'бол',
#  'пят',
#  'минут',
#  '.',
#  'павел',
#  'георгиевич',
#  'долг',
#  'стоя',
#  'на',
#  'безлюдн',
#  'платформ',
#  'и',
#  'слуша',
#  'горяч',
#  'трескотн',
#  'кузнечик',
#  'за',
#  'насып',
#  'степн',
#  'разъезд',
#  '.',
#  'посл',
#  'духот',
#  'вагон',
#  ',',
#  'утомительн',
#  'дорожн',
#  'разговор',
#  'в',
#  'накурен',
#  'куп',
#  'за',
#  'полночн',
#  'преферанс',
#  ',',
#  'ненужн',
#  'знакомств',
#  ',',
#  'посл',
#  'надоедлив',
#  'поскрипыван',
#  'полок',
#  'павл',
#  'георгиевич',
#  'охват',
#  'неправдоподобн',
#  'тишин',
#  ',',
#  'каза',
#  ',',
#  'совс',
#  'как',
#  'в',
#  'детств',
#  '.',
#  'он',
#  'не',
#  'без',
#  'удовольств',
#  'сел',
#  'на',
#  'чемода',
#  ',',
#  'перекинул',
#  'плащ',
#  'через',
#  'плеч',
#  'и',
#  'сидел',
#  'так',
#  ',',
#  'оглядыв',
#  'со',
#  'счастлив',
# ...

# %%
len(stemmed)
# Out:
# 5137

# %%
len(words)
# Out:
# 5137

# %%
len(tokenized_filtered)
# Out:
# 3930

# %% [markdown]
# Neprotivlenie

# %%
with open("Neprotivlenie.txt", encoding="utf-8") as file:
    text_2 = file.read()

# %%
words=word_tokenize(text_2)
words
# Out:
# ['Юрий',
#  'Бондарев',
#  'Непротивление',
#  'Часть',
#  'первая',
#  'Глава',
#  'первая',
#  'Он',
#  'протиснулся',
#  'сквозь',
#  'гущу',
#  'людей',
#  ',',
#  'сквозь',
#  'смешанный',
#  'гул',
#  'голосов',
#  ',',
#  'крики',
#  ',',
#  'смех',
#  ',',
#  'грубую',
#  'ругань',
#  ',',
#  'визгливые',
#  'звуки',
#  'шарманок',
#  ',',
#  'всхлипы',
#  ',',
#  'переборы',
#  'аккордеонов',
#  'и',
#  'хриплые',
#  'солдатские',
#  'песни',
#  ',',
#  'сквозь',
#  'сплошной',
#  'вой',
#  'этой',
#  'пахнущей',
#  'нездоровым',
#  'потом',
#  'толпы',
#  ',',
#  'хаотично',
#  'толкающейся',
#  ',',
#  'сжатой',
#  'в',
#  'каком-то',
#  'сумасшедшем',
#  'круговороте',
#  ',',
#  'торгующей',
#  'всем',
#  ',',
#  'чем',
#  'можно',
#  'было',
#  'торговать',
#  ',',
#  '—',
#  'от',
#  'буханки',
#  'хлеба',
#  ',',
#  'немецкого',
#  'шоколада',
#  ',',
#  'русской',
#  'водки',
#  'до',
#  'армейских',
#  'сапог',
#  ',',
#  'кальсон',
#  'и',
#  'американских',
# ...

# %%
import nltk
nltk.download('stopwords')
stop = stopwords.words('russian')
stop
# Out:
# [nltk_data] Downloading package stopwords to C:\Users\Дима
# [nltk_data]     Титаренко\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# ['и',
#  'в',
#  'во',
#  'не',
#  'что',
#  'он',
#  'на',
#  'я',
#  'с',
#  'со',
#  'как',
#  'а',
#  'то',
#  'все',
#  'она',
#  'так',
#  'его',
#  'но',
#  'да',
#  'ты',
#  'к',
#  'у',
#  'же',
#  'вы',
#  'за',
#  'бы',
#  'по',
#  'только',
#  'ее',
#  'мне',
#  'было',
#  'вот',
#  'от',
#  'меня',
#  'еще',
#  'нет',
#  'о',
#  'из',
#  'ему',
#  'теперь',
#  'когда',
#  'даже',
#  'ну',
#  'вдруг',
#  'ли',
#  'если',
#  'уже',
#  'или',
#  'ни',
#  'быть',
#  'был',
#  'него',
#  'до',
#  'вас',
#  'нибудь',
#  'опять',
#  'уж',
#  'вам',
#  'ведь',
#  'там',
#  'потом',
#  'себя',
#  'ничего',
#  'ей',
#  'может',
#  'они',
#  'тут',
#  'где',
#  'есть',
#  'надо',
#  'ней',
#  'для',
#  'мы',
#  'тебя',
#  'их',
#  'чем',
#  'была',
#  'сам',
#  'чтоб',
#  'без',
#  'будто',
#  'чего',
# ...

# %%
tokenized_filtered = [token for token in words if token not in stop]
tokenized_filtered
# Out:
# ['Юрий',
#  'Бондарев',
#  'Непротивление',
#  'Часть',
#  'первая',
#  'Глава',
#  'первая',
#  'Он',
#  'протиснулся',
#  'сквозь',
#  'гущу',
#  'людей',
#  ',',
#  'сквозь',
#  'смешанный',
#  'гул',
#  'голосов',
#  ',',
#  'крики',
#  ',',
#  'смех',
#  ',',
#  'грубую',
#  'ругань',
#  ',',
#  'визгливые',
#  'звуки',
#  'шарманок',
#  ',',
#  'всхлипы',
#  ',',
#  'переборы',
#  'аккордеонов',
#  'хриплые',
#  'солдатские',
#  'песни',
#  ',',
#  'сквозь',
#  'сплошной',
#  'вой',
#  'пахнущей',
#  'нездоровым',
#  'толпы',
#  ',',
#  'хаотично',
#  'толкающейся',
#  ',',
#  'сжатой',
#  'каком-то',
#  'сумасшедшем',
#  'круговороте',
#  ',',
#  'торгующей',
#  'всем',
#  ',',
#  'торговать',
#  ',',
#  '—',
#  'буханки',
#  'хлеба',
#  ',',
#  'немецкого',
#  'шоколада',
#  ',',
#  'русской',
#  'водки',
#  'армейских',
#  'сапог',
#  ',',
#  'кальсон',
#  'американских',
#  'презервативов',
#  '—',
#  'вырвался',
#  'стадного',
#  'движения',
#  'рынка',
#  ',',
# ...

# %%
stemmer = SnowballStemmer(language='russian')
tokenized = nltk.word_tokenize(text_2)
stemmed = [stemmer.stem(tokenized_filtered) for tokenized_filtered in tokenized]
stemmed
# Out:
# ['юр',
#  'бондар',
#  'непротивлен',
#  'част',
#  'перв',
#  'глав',
#  'перв',
#  'он',
#  'протиснул',
#  'сквоз',
#  'гущ',
#  'люд',
#  ',',
#  'сквоз',
#  'смеша',
#  'гул',
#  'голос',
#  ',',
#  'крик',
#  ',',
#  'смех',
#  ',',
#  'груб',
#  'руган',
#  ',',
#  'визглив',
#  'звук',
#  'шарманок',
#  ',',
#  'всхлип',
#  ',',
#  'перебор',
#  'аккордеон',
#  'и',
#  'хрипл',
#  'солдатск',
#  'песн',
#  ',',
#  'сквоз',
#  'сплошн',
#  'во',
#  'эт',
#  'пахнущ',
#  'нездоров',
#  'пот',
#  'толп',
#  ',',
#  'хаотичн',
#  'толка',
#  ',',
#  'сжат',
#  'в',
#  'каком-т',
#  'сумасшедш',
#  'круговорот',
#  ',',
#  'торг',
#  'всем',
#  ',',
#  'чем',
#  'можн',
#  'был',
#  'торгова',
#  ',',
#  '—',
#  'от',
#  'буханк',
#  'хлеб',
#  ',',
#  'немецк',
#  'шоколад',
#  ',',
#  'русск',
#  'водк',
#  'до',
#  'армейск',
#  'сапог',
#  ',',
#  'кальсон',
#  'и',
#  'американск',
#  'презерватив',
#  '—',
#  'он',
#  'вырва',
#  'из',
#  'эт',
#  'стадн',
#  'движен',
# ...

# %%
len(words)
# Out:
# 125356

# %%
len(tokenized_filtered)
# Out:
# 97781

# %% [markdown]
# Relatives

# %%
with open("Relatives.txt", encoding="utf-8") as file:
    text_3 = file.read()

# %%
words=word_tokenize(text_3)
words
# Out:
# ['Юрий',
#  'Бондарев',
#  'РОДСТВЕННИКИ',
#  '1',
#  'Он',
#  'открыл',
#  'глаза',
#  ',',
#  'увидел',
#  'чужую',
#  'комнату',
#  ',',
#  'до',
#  'горячей',
#  'духоты',
#  'нагретую',
#  'солнцем',
#  ',',
#  'и',
#  'почувствовал',
#  ',',
#  'как',
#  'потное',
#  'лицо',
#  'овеивало',
#  'слабым',
#  'дуновением',
#  'воздуха',
#  '.',
#  'В',
#  'раскрытое',
#  'окно',
#  'тек',
#  'сухой',
#  'жар',
#  'июльского',
#  'утра',
#  '.',
#  'Прямо',
#  'над',
#  'головой',
#  'на',
#  'самом',
#  'солнцепеке',
#  ',',
#  'за',
#  'подоконником',
#  ',',
#  'постукивали',
#  'когтями',
#  'по',
#  'карнизу',
#  'сизые',
#  'голуби',
#  'и',
#  'в',
#  'поисках',
#  'тени',
#  'заглядывали',
#  'в',
#  'комнату',
#  '.',
#  'Потом',
#  'он',
#  'услышал',
#  ',',
#  'как',
#  'где-то',
#  'в',
#  'глубине',
#  'двора',
#  'с',
#  'напором',
#  'зашелестели',
#  'струи',
#  'воды',
#  'о',
#  'листву',
#  ',',
#  'невнятные',
#  'послышались',
#  'голоса',
#  ',',
# ...

# %%
import nltk
nltk.download('stopwords')
stop = stopwords.words('russian')
stop
# Out:
# [nltk_data] Downloading package stopwords to C:\Users\Дима
# [nltk_data]     Титаренко\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# ['и',
#  'в',
#  'во',
#  'не',
#  'что',
#  'он',
#  'на',
#  'я',
#  'с',
#  'со',
#  'как',
#  'а',
#  'то',
#  'все',
#  'она',
#  'так',
#  'его',
#  'но',
#  'да',
#  'ты',
#  'к',
#  'у',
#  'же',
#  'вы',
#  'за',
#  'бы',
#  'по',
#  'только',
#  'ее',
#  'мне',
#  'было',
#  'вот',
#  'от',
#  'меня',
#  'еще',
#  'нет',
#  'о',
#  'из',
#  'ему',
#  'теперь',
#  'когда',
#  'даже',
#  'ну',
#  'вдруг',
#  'ли',
#  'если',
#  'уже',
#  'или',
#  'ни',
#  'быть',
#  'был',
#  'него',
#  'до',
#  'вас',
#  'нибудь',
#  'опять',
#  'уж',
#  'вам',
#  'ведь',
#  'там',
#  'потом',
#  'себя',
#  'ничего',
#  'ей',
#  'может',
#  'они',
#  'тут',
#  'где',
#  'есть',
#  'надо',
#  'ней',
#  'для',
#  'мы',
#  'тебя',
#  'их',
#  'чем',
#  'была',
#  'сам',
#  'чтоб',
#  'без',
#  'будто',
#  'чего',
# ...

# %%
tokenized_filtered = [token for token in words if token not in stop]
tokenized_filtered
# Out:
# ['Юрий',
#  'Бондарев',
#  'РОДСТВЕННИКИ',
#  '1',
#  'Он',
#  'открыл',
#  'глаза',
#  ',',
#  'увидел',
#  'чужую',
#  'комнату',
#  ',',
#  'горячей',
#  'духоты',
#  'нагретую',
#  'солнцем',
#  ',',
#  'почувствовал',
#  ',',
#  'потное',
#  'лицо',
#  'овеивало',
#  'слабым',
#  'дуновением',
#  'воздуха',
#  '.',
#  'В',
#  'раскрытое',
#  'окно',
#  'тек',
#  'сухой',
#  'жар',
#  'июльского',
#  'утра',
#  '.',
#  'Прямо',
#  'головой',
#  'самом',
#  'солнцепеке',
#  ',',
#  'подоконником',
#  ',',
#  'постукивали',
#  'когтями',
#  'карнизу',
#  'сизые',
#  'голуби',
#  'поисках',
#  'тени',
#  'заглядывали',
#  'комнату',
#  '.',
#  'Потом',
#  'услышал',
#  ',',
#  'где-то',
#  'глубине',
#  'двора',
#  'напором',
#  'зашелестели',
#  'струи',
#  'воды',
#  'листву',
#  ',',
#  'невнятные',
#  'послышались',
#  'голоса',
#  ',',
#  'заработал',
#  'холостых',
#  'оборотах',
#  'мотор',
#  'поливальной',
#  'машины',
#  '.',
#  '«',
#  'Что',
#  'это',
#  ',',
#  '?',
# ...

# %%
stemmer = SnowballStemmer(language='russian')
tokenized = nltk.word_tokenize(text_3)
stemmed = [stemmer.stem(tokenized_filtered) for tokenized_filtered in tokenized]
stemmed
# Out:
# ['юр',
#  'бондар',
#  'родственник',
#  '1',
#  'он',
#  'откр',
#  'глаз',
#  ',',
#  'увидел',
#  'чуж',
#  'комнат',
#  ',',
#  'до',
#  'горяч',
#  'духот',
#  'нагрет',
#  'солнц',
#  ',',
#  'и',
#  'почувствова',
#  ',',
#  'как',
#  'потн',
#  'лиц',
#  'овеива',
#  'слаб',
#  'дуновен',
#  'воздух',
#  '.',
#  'в',
#  'раскрыт',
#  'окн',
#  'тек',
#  'сух',
#  'жар',
#  'июльск',
#  'утр',
#  '.',
#  'прям',
#  'над',
#  'голов',
#  'на',
#  'сам',
#  'солнцепек',
#  ',',
#  'за',
#  'подоконник',
#  ',',
#  'постукива',
#  'когт',
#  'по',
#  'карниз',
#  'сиз',
#  'голуб',
#  'и',
#  'в',
#  'поиск',
#  'тен',
#  'заглядыва',
#  'в',
#  'комнат',
#  '.',
#  'пот',
#  'он',
#  'услыша',
#  ',',
#  'как',
#  'где-т',
#  'в',
#  'глубин',
#  'двор',
#  'с',
#  'напор',
#  'зашелестел',
#  'стру',
#  'вод',
#  'о',
#  'листв',
#  ',',
#  'невнятн',
#  'послыша',
#  'голос',
#  ',',
#  'заработа',
#  'на',
#  'холост',
#  'оборот',
#  'мотор',
#  'поливальн',
#  'машин',
# ...

# %%
len(words)
# Out:
# 57096

# %%
len(tokenized_filtered)
# Out:
# 44297

# %% [markdown]
# Silence

# %%
with open("Silence.txt", encoding="utf-8") as file:
    text_4=file.read()

# %%
words=word_tokenize(text_4)
words
# Out:
# ['Юрий',
#  'Бондарев',
#  'Тишина',
#  'ЧАСТЬ',
#  'ПЕРВАЯ',
#  '.',
#  '1945',
#  'ГОД',
#  '1',
#  'Выбиваясь',
#  'из',
#  'сил',
#  ',',
#  'он',
#  'бежал',
#  'посреди',
#  'лунной',
#  'мостовой',
#  'мимо',
#  'зияющих',
#  'подъездов',
#  ',',
#  'мимо',
#  'разбитых',
#  'фонарей',
#  ',',
#  'поваленных',
#  'заборов',
#  '.',
#  'Он',
#  'видел',
#  ':',
#  'черные',
#  ',',
#  'лохматые',
#  ',',
#  'как',
#  'пауки',
#  ',',
#  'самолеты',
#  'с',
#  'хищно',
#  'вытянутыми',
#  'лапами',
#  'беззвучно',
#  'кружили',
#  'над',
#  'ним',
#  ',',
#  'широкими',
#  'тенями',
#  'проплывали',
#  'меж',
#  'заводских',
#  'труб',
#  ',',
#  'снижаясь',
#  'над',
#  'ущельем',
#  'улицы',
#  '.',
#  'Он',
#  'ясно',
#  'видел',
#  ',',
#  'что',
#  'это',
#  'были',
#  'не',
#  'самолеты',
#  ',',
#  'а',
#  'угрюмые',
#  'гигантские',
#  'пауки',
#  ',',
#  'но',
#  'в',
#  'то',
#  'же',
#  'время',
#  'это',
#  'были',
#  'самолеты',
#  ',',
#  'и',
#  'они',
# ...

# %%
import nltk
nltk.download('stopwords')
stop = stopwords.words('russian')
stop
# Out:
# [nltk_data] Downloading package stopwords to C:\Users\Дима
# [nltk_data]     Титаренко\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# ['и',
#  'в',
#  'во',
#  'не',
#  'что',
#  'он',
#  'на',
#  'я',
#  'с',
#  'со',
#  'как',
#  'а',
#  'то',
#  'все',
#  'она',
#  'так',
#  'его',
#  'но',
#  'да',
#  'ты',
#  'к',
#  'у',
#  'же',
#  'вы',
#  'за',
#  'бы',
#  'по',
#  'только',
#  'ее',
#  'мне',
#  'было',
#  'вот',
#  'от',
#  'меня',
#  'еще',
#  'нет',
#  'о',
#  'из',
#  'ему',
#  'теперь',
#  'когда',
#  'даже',
#  'ну',
#  'вдруг',
#  'ли',
#  'если',
#  'уже',
#  'или',
#  'ни',
#  'быть',
#  'был',
#  'него',
#  'до',
#  'вас',
#  'нибудь',
#  'опять',
#  'уж',
#  'вам',
#  'ведь',
#  'там',
#  'потом',
#  'себя',
#  'ничего',
#  'ей',
#  'может',
#  'они',
#  'тут',
#  'где',
#  'есть',
#  'надо',
#  'ней',
#  'для',
#  'мы',
#  'тебя',
#  'их',
#  'чем',
#  'была',
#  'сам',
#  'чтоб',
#  'без',
#  'будто',
#  'чего',
# ...

# %%
tokenized_filtered = [token for token in words if token not in stop]
tokenized_filtered
# Out:
# ['Юрий',
#  'Бондарев',
#  'Тишина',
#  'ЧАСТЬ',
#  'ПЕРВАЯ',
#  '.',
#  '1945',
#  'ГОД',
#  '1',
#  'Выбиваясь',
#  'сил',
#  ',',
#  'бежал',
#  'посреди',
#  'лунной',
#  'мостовой',
#  'мимо',
#  'зияющих',
#  'подъездов',
#  ',',
#  'мимо',
#  'разбитых',
#  'фонарей',
#  ',',
#  'поваленных',
#  'заборов',
#  '.',
#  'Он',
#  'видел',
#  ':',
#  'черные',
#  ',',
#  'лохматые',
#  ',',
#  'пауки',
#  ',',
#  'самолеты',
#  'хищно',
#  'вытянутыми',
#  'лапами',
#  'беззвучно',
#  'кружили',
#  ',',
#  'широкими',
#  'тенями',
#  'проплывали',
#  'меж',
#  'заводских',
#  'труб',
#  ',',
#  'снижаясь',
#  'ущельем',
#  'улицы',
#  '.',
#  'Он',
#  'ясно',
#  'видел',
#  ',',
#  'это',
#  'самолеты',
#  ',',
#  'угрюмые',
#  'гигантские',
#  'пауки',
#  ',',
#  'время',
#  'это',
#  'самолеты',
#  ',',
#  'сверху',
#  'выследили',
#  ',',
#  'одного',
#  'среди',
#  'развалин',
#  'погибшего',
#  'города',
#  '.',
#  'Он',
#  'бежал',
#  'окраине',
#  ',',
#  ',',
#  'высоте',
# ...

# %%
stemmer = SnowballStemmer(language='russian')
tokenized = nltk.word_tokenize(text_4)
stemmed = [stemmer.stem(tokenized_filtered) for tokenized_filtered in tokenized]
stemmed
# Out:
# ['юр',
#  'бондар',
#  'тишин',
#  'част',
#  'перв',
#  '.',
#  '1945',
#  'год',
#  '1',
#  'выбив',
#  'из',
#  'сил',
#  ',',
#  'он',
#  'бежа',
#  'посред',
#  'лун',
#  'мостов',
#  'мим',
#  'зия',
#  'подъезд',
#  ',',
#  'мим',
#  'разбит',
#  'фонар',
#  ',',
#  'повален',
#  'забор',
#  '.',
#  'он',
#  'видел',
#  ':',
#  'черн',
#  ',',
#  'лохмат',
#  ',',
#  'как',
#  'паук',
#  ',',
#  'самолет',
#  'с',
#  'хищн',
#  'вытянут',
#  'лап',
#  'беззвучн',
#  'круж',
#  'над',
#  'ним',
#  ',',
#  'широк',
#  'тен',
#  'проплыва',
#  'меж',
#  'заводск',
#  'труб',
#  ',',
#  'сниж',
#  'над',
#  'ущел',
#  'улиц',
#  '.',
#  'он',
#  'ясн',
#  'видел',
#  ',',
#  'что',
#  'эт',
#  'был',
#  'не',
#  'самолет',
#  ',',
#  'а',
#  'угрюм',
#  'гигантск',
#  'паук',
#  ',',
#  'но',
#  'в',
#  'то',
#  'же',
#  'врем',
#  'эт',
#  'был',
#  'самолет',
#  ',',
#  'и',
#  'он',
#  'сверх',
#  'выслед',
#  'ег',
#  ',',
#  'одн',
#  'сред',
#  'развалин',
#  'погибш',
# ...

# %%
len(words)
# Out:
# 148946

# %%
len(tokenized_filtered)
# Out:
# 118509

# %% [markdown]
# Warm_snow

# %%
with open('Warm_snow.txt', encoding="utf-8") as file:
    text_5=file.read()

# %%
words=word_tokenize(text_5)
words
# Out:
# ['Юрий',
#  'Бондарев',
#  'ГОРЯЧИЙ',
#  'СНЕГ',
#  'Глава',
#  'первая',
#  'Кузнецову',
#  'не',
#  'спалось',
#  '.',
#  'Все',
#  'сильнее',
#  'стучало',
#  ',',
#  'гремело',
#  'по',
#  'крыше',
#  'вагона',
#  ',',
#  'вьюжно',
#  'ударяли',
#  'нахлесты',
#  'ветра',
#  ',',
#  'все',
#  'плотнее',
#  'забивало',
#  'снегом',
#  'едва',
#  'угадываемое',
#  'оконце',
#  'над',
#  'нарами',
#  '.',
#  'Паровоз',
#  'с',
#  'диким',
#  ',',
#  'раздирающим',
#  'метель',
#  'ревом',
#  'гнал',
#  'эшелон',
#  'в',
#  'ночных',
#  'полях',
#  ',',
#  'в',
#  'белой',
#  ',',
#  'несущейся',
#  'со',
#  'всех',
#  'сторон',
#  'мути',
#  ',',
#  'и',
#  'в',
#  'гремучей',
#  'темноте',
#  'вагона',
#  ',',
#  'сквозь',
#  'мерзлый',
#  'визг',
#  'колес',
#  ',',
#  'сквозь',
#  'тревожные',
#  'всхлипы',
#  ',',
#  'бормотание',
#  'во',
#  'сне',
#  'солдат',
#  'был',
#  'слышен',
#  'этот',
#  'непрерывно',
#  'предупреждающий',
#  'кого-то',
#  'рев',
#  'паровоза',
# ...

# %%
import nltk
nltk.download('stopwords')
stop = stopwords.words('russian')
stop
# Out:
# [nltk_data] Downloading package stopwords to C:\Users\Дима
# [nltk_data]     Титаренко\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# ['и',
#  'в',
#  'во',
#  'не',
#  'что',
#  'он',
#  'на',
#  'я',
#  'с',
#  'со',
#  'как',
#  'а',
#  'то',
#  'все',
#  'она',
#  'так',
#  'его',
#  'но',
#  'да',
#  'ты',
#  'к',
#  'у',
#  'же',
#  'вы',
#  'за',
#  'бы',
#  'по',
#  'только',
#  'ее',
#  'мне',
#  'было',
#  'вот',
#  'от',
#  'меня',
#  'еще',
#  'нет',
#  'о',
#  'из',
#  'ему',
#  'теперь',
#  'когда',
#  'даже',
#  'ну',
#  'вдруг',
#  'ли',
#  'если',
#  'уже',
#  'или',
#  'ни',
#  'быть',
#  'был',
#  'него',
#  'до',
#  'вас',
#  'нибудь',
#  'опять',
#  'уж',
#  'вам',
#  'ведь',
#  'там',
#  'потом',
#  'себя',
#  'ничего',
#  'ей',
#  'может',
#  'они',
#  'тут',
#  'где',
#  'есть',
#  'надо',
#  'ней',
#  'для',
#  'мы',
#  'тебя',
#  'их',
#  'чем',
#  'была',
#  'сам',
#  'чтоб',
#  'без',
#  'будто',
#  'чего',
# ...

# %%
tokenized_filtered = [token for token in words if token not in stop]
tokenized_filtered
# Out:
# ['Юрий',
#  'Бондарев',
#  'ГОРЯЧИЙ',
#  'СНЕГ',
#  'Глава',
#  'первая',
#  'Кузнецову',
#  'спалось',
#  '.',
#  'Все',
#  'сильнее',
#  'стучало',
#  ',',
#  'гремело',
#  'крыше',
#  'вагона',
#  ',',
#  'вьюжно',
#  'ударяли',
#  'нахлесты',
#  'ветра',
#  ',',
#  'плотнее',
#  'забивало',
#  'снегом',
#  'едва',
#  'угадываемое',
#  'оконце',
#  'нарами',
#  '.',
#  'Паровоз',
#  'диким',
#  ',',
#  'раздирающим',
#  'метель',
#  'ревом',
#  'гнал',
#  'эшелон',
#  'ночных',
#  'полях',
#  ',',
#  'белой',
#  ',',
#  'несущейся',
#  'сторон',
#  'мути',
#  ',',
#  'гремучей',
#  'темноте',
#  'вагона',
#  ',',
#  'сквозь',
#  'мерзлый',
#  'визг',
#  'колес',
#  ',',
#  'сквозь',
#  'тревожные',
#  'всхлипы',
#  ',',
#  'бормотание',
#  'сне',
#  'солдат',
#  'слышен',
#  'непрерывно',
#  'предупреждающий',
#  'кого-то',
#  'рев',
#  'паровоза',
#  ',',
#  'чудилось',
#  'Кузнецову',
#  ',',
#  ',',
#  'впереди',
#  ',',
#  'метелью',
#  ',',
#  'мутно',
#  'проступало',
# ...

# %%
stemmer = SnowballStemmer(language='russian')
tokenized = nltk.word_tokenize(text_5)
stemmed = [stemmer.stem(tokenized_filtered) for tokenized_filtered in tokenized]
stemmed
# Out:
# ['юр',
#  'бондар',
#  'горяч',
#  'снег',
#  'глав',
#  'перв',
#  'кузнецов',
#  'не',
#  'спал',
#  '.',
#  'все',
#  'сильн',
#  'стуча',
#  ',',
#  'гремел',
#  'по',
#  'крыш',
#  'вагон',
#  ',',
#  'вьюжн',
#  'ударя',
#  'нахлест',
#  'ветр',
#  ',',
#  'все',
#  'плотн',
#  'забива',
#  'снег',
#  'едв',
#  'угадыва',
#  'оконц',
#  'над',
#  'нар',
#  '.',
#  'паровоз',
#  'с',
#  'дик',
#  ',',
#  'раздира',
#  'метел',
#  'рев',
#  'гнал',
#  'эшелон',
#  'в',
#  'ночн',
#  'пол',
#  ',',
#  'в',
#  'бел',
#  ',',
#  'несущ',
#  'со',
#  'всех',
#  'сторон',
#  'мут',
#  ',',
#  'и',
#  'в',
#  'гремуч',
#  'темнот',
#  'вагон',
#  ',',
#  'сквоз',
#  'мерзл',
#  'визг',
#  'колес',
#  ',',
#  'сквоз',
#  'тревожн',
#  'всхлип',
#  ',',
#  'бормотан',
#  'во',
#  'сне',
#  'солдат',
#  'был',
#  'слыш',
#  'этот',
#  'непрерывн',
#  'предупрежда',
#  'кого-т',
#  'рев',
#  'паровоз',
#  ',',
#  'и',
#  'чуд',
#  'кузнецов',
#  ',',
#  'что',
#  'там',
#  ',',
# ...

# %%
len(words)
# Out:
# 136251

# %%
len(tokenized_filtered)
# Out:
# 108042

# %% [markdown]
# Косинусное сходстово "Последние залпы и Простите нас!"

# %%
word = re.compile(r"\w+")

with open("Last_volleys.txt", encoding="utf-8") as file:
    text = file.read()
with open("Forgive_us!.txt", encoding="utf-8") as file:
    text_1 = file.read()

def cosine_similarity(vector_1, vector_2):
    inter = set(vector_1.keys()) & set(vector_1.keys())
    numer = sum([vector_1[i] * vector_2[i] for i in inter])# числитель DF

    s_1 = sum([vector_1[i] ** 2 for i in list(vector_1.keys())])
    s_2 = sum([vector_2[i] ** 2 for i in list(vector_2.keys())])
    deno = math.sqrt(s_1) * math.sqrt(s_2) #Знаменатель IDF

    if not deno:
        return 0.0
    else:
        return float(numer) / deno # Cos

def generate_vectors(sent):
    w = word.findall(sent) #поиск всех слов в предложении
    return Count(w)

vec_1 = generate_vectors(text)
vec_2 = generate_vectors(text_1)

cos = cosine_similarity(vec_1, vec_2)

print("Косинусное сходстово:", cos)
# Out:
# Косинусное сходстово: 0.8790189367386265

# %% [markdown]
# Косинусное сходство " Последние залпы и Непротивление"

# %%
word = re.compile(r"\w+")

with open("Last_volleys.txt", encoding="utf-8") as file:
    text = file.read()
with open("Neprotivlenie.txt", encoding="utf-8") as file:
    text_2 = file.read()

def cosine_similarity(vector_1, vector_2):
    inter = set(vector_1.keys()) & set(vector_1.keys())
    numer = sum([vector_1[i] * vector_2[i] for i in inter])

    s_1 = sum([vector_1[i] ** 2 for i in list(vector_1.keys())])
    s_2 = sum([vector_2[i] ** 2 for i in list(vector_2.keys())])
    deno = math.sqrt(s_1) * math.sqrt(s_2)

    if not deno:
        return 0.0
    else:
        return float(numer) / deno

def generate_vectors(sent):
    w = word.findall(sent)
    return Count(w)

vec_1 = generate_vectors(text)
vec_2 = generate_vectors(text_2)

cos = cosine_similarity(vec_1, vec_2)

print("Косинусное сходстово", cos)
# Out:
# Косинусное сходстово 0.9371650617841418

# %% [markdown]
# Косинусное сходство "Последние залпы и Непротивление"

# %%
word = re.compile(r"\w+")

with open("Last_volleys.txt", encoding="utf-8") as file:
    text = file.read()
with open("Neprotivlenie.txt", encoding="utf-8") as file:
    text_3 = file.read()

def cosine_similarity(vector_1, vector_2):
    inter = set(vector_1.keys()) & set(vector_1.keys())
    numer = sum([vector_1[i] * vector_2[i] for i in inter])

    s_1 = sum([vector_1[i] ** 2 for i in list(vector_1.keys())])
    s_2 = sum([vector_2[i] ** 2 for i in list(vector_2.keys())])
    deno = math.sqrt(s_1) * math.sqrt(s_2)

    if not deno:
        return 0.0
    else:
        return float(numer) / deno

def generate_vectors(sent):
    w = word.findall(sent)
    return Count(w)

vec_1 = generate_vectors(text)
vec_2 = generate_vectors(text_3)

cos = cosine_similarity(vec_1, vec_2)

print("Косинусное сходстово:", cos)
# Out:
# Косинусное сходстово: 0.9371650617841418

# %% [markdown]
# Косинусное сходство "Последние залпы и Родственники"

# %%
word = re.compile(r"\w+")

with open("Last_volleys.txt", encoding="utf-8") as file:
    text = file.read()
with open("Relatives.txt", encoding="utf-8") as file:
    text_4 = file.read()

def cosine_similarity(vector_1, vector_2):
    inter = set(vector_1.keys()) & set(vector_1.keys())
    numer = sum([vector_1[i] * vector_2[i] for i in inter])

    s_1 = sum([vector_1[i] ** 2 for i in list(vector_1.keys())])
    s_2 = sum([vector_2[i] ** 2 for i in list(vector_2.keys())])
    deno = math.sqrt(s_1) * math.sqrt(s_2)

    if not deno:
        return 0.0
    else:
        return float(numer) / deno

def generate_vectors(sent):
    w = word.findall(sent)
    return Count(w)

vec_1 = generate_vectors(text)
vec_2 = generate_vectors(text_4)

cos = cosine_similarity(vec_1, vec_2)

print("Косинусное сходстово:", cos)
# Out:
# Косинусное сходстово: 0.923255620137849

# %% [markdown]
# Косинусное сходство "Последние залпы и Тишина"

# %%
word = re.compile(r"\w+")

with open("Last_volleys.txt", encoding="utf-8") as file:
    text = file.read()
with open("Silence.txt", encoding="utf-8") as file:
    text_5 = file.read()

def cosine_similarity(vector_1, vector_2):
    inter = set(vector_1.keys()) & set(vector_1.keys())
    numer = sum([vector_1[i] * vector_2[i] for i in inter])

    s_1 = sum([vector_1[i] ** 2 for i in list(vector_1.keys())])
    s_2 = sum([vector_2[i] ** 2 for i in list(vector_2.keys())])
    deno = math.sqrt(s_1) * math.sqrt(s_2)

    if not deno:
        return 0.0
    else:
        return float(numer) / deno

def generate_vectors(sent):
    w = word.findall(sent)
    return Count(w)

vec_1 = generate_vectors(text)
vec_2 = generate_vectors(text_5)

cos = cosine_similarity(vec_1, vec_2)

print("Косинусное сходстово:", cos)
# Out:
# Косинусное сходстово: 0.9373927937035448

# %% [markdown]
# Косинусное сходство "Последние залпы и Горячий снег"

# %%
word = re.compile(r"\w+")

with open("Last_volleys.txt", encoding="utf-8") as file:
    text = file.read()
with open("Warm_snow.txt", encoding="utf-8") as file:
    text_1 = file.read()

def cosine_similarity(vector_1, vector_2):
    inter = set(vector_1.keys()) & set(vector_1.keys())
    numer = sum([vector_1[i] * vector_2[i] for i in inter]) # числитель DF

    s_1 = sum([vector_1[i] ** 2 for i in list(vector_1.keys())])
    s_2 = sum([vector_2[i] ** 2 for i in list(vector_2.keys())])
    deno = math.sqrt(s_1) * math.sqrt(s_2) #Знаменатель IDF

    if not deno:
        return 0.0
    else:
        return float(numer) / deno # Cos

def generate_vectors(sent):
    w = word.findall(sent) #поиск всех слов в предложении
    return Count(w)

vec_1 = generate_vectors(text)
vec_2 = generate_vectors(text_1)

cos = cosine_similarity(vec_1, vec_2)

print("Косинусное сходстово:", cos)
# Out:
# Косинусное сходстово: 0.9450087598200215
